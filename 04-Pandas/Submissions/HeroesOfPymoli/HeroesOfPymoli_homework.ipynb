# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
purchase_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Purchase ID  780 non-null    int64
#  1   SN           780 non-null    object
#  2   Age          780 non-null    int64
#  3   Gender       780 non-null    object
#  4   Item ID      780 non-null    int64
#  5   Item Name    780 non-null    object
#  6   Price        780 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 42.8+ KB

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purch_num = purchase_data["SN"].unique()
purch_num
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Chanosian48', 'Inguron55', 'Haisrisuir60', 'Saelaephos52',
#        'Assjaskan73', 'Saesrideu94', 'Lisassa64', 'Lisirra25',
#        'Zontibe81', 'Reunasu60', 'Chamalo71', 'Iathenudil29',
#        'Phiarithdeu40', 'Siarithria38', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Reulae52',
#        'Sondilsaya62', 'Aerithriaphos45', 'Assosia88', 'Aidaillodeu39',
#        'Aelly27', 'Tyeosri53', 'Haerith37', 'Yasrisu92', 'Chanuchi25',
#        'Asur96', 'Iaralrgue74', 'Chanosia34', 'Aelin32', 'Ilosianya35',
#        'Zhisrisu83', 'Phaelap26', 'Raesty92', 'Palyon91', 'Tyisur83',
#        'Yaliru88', 'Yadanu52', 'Jiskimya77', 'Yadaphos40', 'Alo38',
# ...

# %%
number_of_purchases = purchase_data["SN"].count()
number_of_purchases
# Out:
# 780

# %%
unique_sn =len(purch_num)
unique_sn
# Out:
# 576

# %%
players_df = pd.DataFrame({"Total Number of Players": unique_sn}, index=[0])
players_df
# Out:
#    Total Number of Players
# 0                      576

# %%
purchase_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Purchase ID  780 non-null    int64
#  1   SN           780 non-null    object
#  2   Age          780 non-null    int64
#  3   Gender       780 non-null    object
#  4   Item ID      780 non-null    int64
#  5   Item Name    780 non-null    object
#  6   Price        780 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 42.8+ KB

# %%
unique2 = purchase_data["Item ID"].unique()
unique_id = len(unique2)
unique_id
# Out:
# 179

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
average = purchase_data["Price"].mean()
average
# Out:
# 3.050987179487176

# %%
averageround= np.round(average, decimals=2)
averageround
# Out:
# 3.05

# %%
total = purchase_data["Price"].sum()
total
# Out:
# 2379.77

# %%
new_df = pd.DataFrame({"Number of Unique Items": unique_id,
                        "Average Price": averageround,
                        "Number of Purchases": number_of_purchases,
                        "Total Revenue": total}, index=[0])
new_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179           3.05                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
player_data = purchase_data.loc[:,["SN", "Age", "Gender"]].drop_duplicates().reset_index(drop=True)
player_data.head()
# Out:
#               SN  Age Gender
# 0        Lisim78   20   Male
# 1    Lisovynya38   40   Male
# 2     Ithergue48   24   Male
# 3  Chamassasya86   24   Male
# 4      Iskosia90   23   Male

# %%
# Write code that will pull the count of gender for players based on the unique ID because players purchased more 
# than one game
player_summary = pd.DataFrame(player_data.groupby("Gender").size(), columns=["Count"])
player_summary["Percentage"] = player_summ["Count"] / len(player_data) * 100
player_summary
# Out:
#                        Count  Percentage
# Gender
# Female                    81   14.062500
# Male                     484   84.027778
# Other / Non-Disclosed     11    1.909722

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_purch_cnt = purchase_data.groupby("Gender").size()
gender_price_cnt = purchase_data.groupby("Gender").Price.mean()
gender_price_sum = purchase_data.groupby("Gender").Price.sum()

# %%
gender_df = pd.DataFrame([gender_purch_cnt, gender_price_cnt, gender_price_sum]).T
gender_df.columns = ["Total Purchases", "Average Purchases", "Sum Purchases"]
gender_df['Purchases by Player Avg'] = gender_df["Sum Purchases"] / player_summary["Count"]
                        
gender_df
# Out:
#                        Total Purchases  Average Purchases  Sum Purchases  \
# Gender
# Female                           113.0           3.203009         361.94
# Male                             652.0           3.017853        1967.64
# Other / Non-Disclosed             15.0           3.346000          50.19
#
#                        Purchases by Player Avg
# Gender
# Female                                4.468395
# Male                                  4.065372
# Other / Non-Disclosed                 4.562727

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0,9,14,19,24,29,34,39,10000]

# Create labels for these bins
group_labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
player_data["AgeGroup"] = pd.cut(player_data["Age"], bins, labels=group_labels, include_lowest=True)
player_data
# Out:
#                 SN  Age  Gender AgeGroup
# 0          Lisim78   20    Male    20-24
# 1      Lisovynya38   40    Male      40+
# 2       Ithergue48   24    Male    20-24
# 3    Chamassasya86   24    Male    20-24
# 4        Iskosia90   23    Male    20-24
# ..             ...  ...     ...      ...
# 571         Hala31   21    Male    20-24
# 572     Jiskjask80   11    Male    10-14
# 573     Aethedru70   21  Female    20-24
# 574     Yathecal72   20    Male    20-24
# 575        Sisur91    7    Male      <10
#
# [576 rows x 4 columns]

# %%
player_age_summary = pd.DataFrame(player_data.groupby("AgeGroup").size(), columns=["Count"])
player_age_summary["Percentage"] = player_age_summary["Count"] / len(player_data) * 100
player_age_summary
# Out:
#           Count  Percentage
# AgeGroup
# <10          17    2.951389
# 10-14        22    3.819444
# 15-19       107   18.576389
# 20-24       258   44.791667
# 25-29        77   13.368056
# 30-34        52    9.027778
# 35-39        31    5.381944
# 40+          12    2.083333

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data["AgeGroup"] = pd.cut(purchase_data["Age"], bins, labels=group_labels, include_lowest=True)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price AgeGroup
# 0  Extraction, Quickblade Of Trembling Hands   3.53    20-24
# 1                          Frenzied Scimitar   1.56      40+
# 2                               Final Critic   4.88    20-24
# 3                                Blindscythe   3.27    20-24
# 4                                       Fury   1.44    20-24

# %%
age_purchase_cnt = purchase_data.groupby("AgeGroup").size()
age_price_mean = purchase_data.groupby("AgeGroup").Price.mean()
age_price_sum = purchase_data.groupby("AgeGroup").Price.sum()

# %%
age_purchase_summary = pd.DataFrame([age_purchase_cnt, age_price_mean, age_price_sum]).T
age_purchase_summary.columns = ["Total Purchases", "Average Purchases", "Sum Purchases"]
age_purchase_summary['Purchases by Player Avg'] = age_purch_summ["Sum Purchases"] / player_age_summary["Count"]

age_purchase_summary
# Out:
#           Total Purchases  Average Purchases  Sum Purchases  \
# AgeGroup
# <10                  23.0           3.353478          77.13
# 10-14                28.0           2.956429          82.78
# 15-19               136.0           3.035956         412.89
# 20-24               365.0           3.052219        1114.06
# 25-29               101.0           2.900990         293.00
# 30-34                73.0           2.931507         214.00
# 35-39                41.0           3.601707         147.67
# 40+                  13.0           2.941538          38.24
#
#           Purchases by Player Avg
# AgeGroup
# <10                      4.537059
# 10-14                    3.762727
# 15-19                    3.858785
# 20-24                    4.318062
# 25-29                    3.805195
# 30-34                    4.115385
# 35-39                    4.763548
# 40+                      3.186667

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
sn_purchase_cnt = purchase_data.groupby("SN").size()
sn_price_cnt = purchase_data.groupby("SN").Price.mean()
sn_price_sum = purchase_data.groupby("SN").Price.sum()

# %%
sn_purchase_summary = pd.DataFrame([sn_purchase_cnt, sn_price_cnt, sn_price_sum]).T
sn_purchase_summary.columns = ["Total Purchases", "Average Purchases", "Sum Purchases"]
top_spenders = sn_purchase_summary.sort_values(by="Sum Purchases", ascending=False)
top_spenders.head()
# Out:
#              Total Purchases  Average Purchases  Sum Purchases
# SN
# Lisosia93                5.0           3.792000          18.96
# Idastidru52              4.0           3.862500          15.45
# Chamjask73               3.0           4.610000          13.83
# Iral74                   4.0           3.405000          13.62
# Iskadarya95              3.0           4.366667          13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
item_data = purchase_data.loc[:, ["Item ID", "Item Name", "Price"]]
item_data.head()
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands   3.53
# 1      143                          Frenzied Scimitar   1.56
# 2       92                               Final Critic   4.88
# 3      100                                Blindscythe   3.27
# 4      131                                       Fury   1.44

# %%
item_purchase_cnt = purchase_data.groupby(["Item ID", "Item Name"]).size()
item_price_cnt = purchase_data.groupby(["Item ID", "Item Name"]).Price.mean()
item_price_sum = purchase_data.groupby(["Item ID", "Item Name"]).Price.sum()

# %%
item_purchase_summary = pd.DataFrame([item_purchase_cnt, item_price_cnt, item_price_sum]).T
item_purchase_summary.columns = ["Total Purchases", "Average Purchases", "Sum Purchases"]
most_popular_items = item_purchase_summary.sort_values(by="Total Purchases", ascending=False)
most_popular_items.head()
# Out:
#                                                       Total Purchases  \
# Item ID Item Name
# 92      Final Critic                                             13.0
# 178     Oathbreaker, Last Hope of the Breaking Storm             12.0
# 145     Fiery Glass Crusader                                      9.0
# 132     Persuasion                                                9.0
# 108     Extraction, Quickblade Of Trembling Hands                 9.0
#
#                                                       Average Purchases  \
# Item ID Item Name
# 92      Final Critic                                           4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm           4.230000
# 145     Fiery Glass Crusader                                   4.580000
# 132     Persuasion                                             3.221111
# 108     Extraction, Quickblade Of Trembling Hands              3.530000
#
#                                                       Sum Purchases
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_items = item_purchase_summary.sort_values(by="Sum Purchases", ascending=False)
most_profitable_items.head()
# Out:
#                                                       Total Purchases  \
# Item ID Item Name
# 92      Final Critic                                             13.0
# 178     Oathbreaker, Last Hope of the Breaking Storm             12.0
# 82      Nirvana                                                   9.0
# 145     Fiery Glass Crusader                                      9.0
# 103     Singed Scalpel                                            8.0
#
#                                                       Average Purchases  \
# Item ID Item Name
# 92      Final Critic                                           4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm           4.230000
# 82      Nirvana                                                4.900000
# 145     Fiery Glass Crusader                                   4.580000
# 103     Singed Scalpel                                         4.350000
#
#                                                       Sum Purchases
# ...

# %% [markdown]
# # Write to excel file to use in data analysis

# %%
with pd.ExcelWriter('PymoliData.xlsx') as writer:
    purchase_data.to_excel(writer, sheet_name='Purchase_Info_Data')
    players_df.to_excel(writer, sheet_name='Total_Number_of_Players')
    new_df.to_excel(writer, sheet_name='Purchasing_Analysis_Total')
    player_summary.to_excel(writer, sheet_name='Gender_Demographics')
    gender_df.to_excel(writer, sheet_name='Purchasing_Analysis_Gender')
    player_age_summary.to_excel(writer, sheet_name='Age_Demographics')
    age_purchase_summary.to_excel(writer, sheet_name='Purchasing_Analysis_Age')
    top_spenders.to_excel(writer, sheet_name='Top_Spenders')
    most_popular_items.to_excel(writer, sheet_name='Most_Popular_Items')
    most_profitable_items.to_excel(writer, sheet_name='Most_Profitable_Items')
