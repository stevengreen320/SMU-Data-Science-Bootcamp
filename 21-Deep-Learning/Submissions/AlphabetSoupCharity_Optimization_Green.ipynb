# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("/content/drive/MyDrive/Colab SMU/Deep Learning Homework/Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EIN                     34299 non-null  int64
#  1   NAME                    34299 non-null  object
#  2   APPLICATION_TYPE        34299 non-null  object
#  3   AFFILIATION             34299 non-null  object
#  4   CLASSIFICATION          34299 non-null  object
#  5   USE_CASE                34299 non-null  object
#  6   ORGANIZATION            34299 non-null  object
#  7   STATUS                  34299 non-null  int64
#  8   INCOME_AMT              34299 non-null  object
#  9   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  10  ASK_AMT                 34299 non-null  int64
#  11  IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 3.1+ MB

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis =1)

# %%
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION  ... ASK_AMT IS_SUCCESSFUL
# 0              T10       Independent  ...    5000             1
# 1               T3       Independent  ...  108590             1
# 2               T5  CompanySponsored  ...    5000             0
# 3               T3  CompanySponsored  ...    6692             1
# 4               T3       Independent  ...  142590             1
#
# [5 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
for col in application_df.columns:
  if col not in ["STATUS", "ASK_AMT"]:
    print(col)
    print(len(application_df[col].value_counts()))
    print()
# Out:
# APPLICATION_TYPE
# 17
#
# AFFILIATION
# 6
#
# CLASSIFICATION
# 71
#
# USE_CASE
# 5
#
# ORGANIZATION
# 4
#
# INCOME_AMT
# 9
#
# SPECIAL_CONSIDERATIONS
# 2
#
# IS_SUCCESSFUL
# 2

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.APPLICATION_TYPE.value_counts().plot(kind= "bar")
plt.show()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

cutoff = 50
app_vals = application_df.APPLICATION_TYPE.value_counts()
application_types_to_replace = list(app_vals[app_vals < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2150        1
# C2380        1
# C2500        1
# C2570        1
# C1900        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
application_df.CLASSIFICATION.value_counts().plot.kde()
plt.show()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_vals = application_df.CLASSIFICATION.value_counts()
class_vals[class_vals > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1257        5
# C1600        5
# C2710        3
# C1260        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 35
class_vals = application_df.CLASSIFICATION.value_counts()
classifications_to_replace = list(class_vals[class_vals < cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      355
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                         1                         0
# 1       1   108590  ...                         1                         0
# 2       1     5000  ...                         1                         0
# 3       1     6692  ...                         1                         0
# 4       1   142590  ...                         1                         0
#
# [5 rows x 57 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop("IS_SUCCESSFUL", axis = 1)
y = application_df.IS_SUCCESSFUL

# Split the preprocessed data into a training and testing dataset
# Use sklearn to split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365],
#        [ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365],
#        [ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365],
#        ...,
#        [ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365],
#        [ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365],
#        [ 0.01394306, -0.03145581, -0.04043991, ..., -0.07126932,
#          0.02858365, -0.02858365]])

# %%
X.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                         1                         0
# 1       1   108590  ...                         1                         0
# 2       1     5000  ...                         1                         0
# 3       1     6692  ...                         1                         0
# 4       1   142590  ...                         1                         0
#
# [5 rows x 56 columns]

# %%
print(len(X.columns))
# Out:
# 56

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=128, activation="leaky_relu", input_dim=len(X.columns)))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=128, activation="leaky_relu"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=32, activation="leaky_relu"))

# Fourth hidden layer
nn_model.add(tf.keras.layers.Dense(units=16, activation="leaky_relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7296
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 28,481
# Trainable params: 28,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])
# nn_model.compile(loss="binary_crossentropy", optimizer="NAdam", metrics=["accuracy"])
# nn_model.compile(loss="binary_crossentropy", optimizer="Adamax", metrics=["accuracy"])
# nn_model.compile(loss="binary_crossentropy", optimizer="Adadelta", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5667 - accuracy: 0.7234
# Epoch 2/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5536 - accuracy: 0.7304
# Epoch 3/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5504 - accuracy: 0.7300
# Epoch 4/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5490 - accuracy: 0.7310
# Epoch 5/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5477 - accuracy: 0.7308
# Epoch 6/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5470 - accuracy: 0.7329
# Epoch 7/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5464 - accuracy: 0.7322
# Epoch 8/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5459 - accuracy: 0.7342
# Epoch 9/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5453 - accuracy: 0.7336
# Epoch 10/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5443 - accuracy: 0.7346
# Epoch 11/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7346
# Epoch 12/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5435 - accuracy: 0.7339
# Epoch 13/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7355
# Epoch 14/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5426 - accuracy: 0.7364
# Epoch 15/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5422 - accuracy: 0.7346
# Epoch 16/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7359
# Epoch 17/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5406 - accuracy: 0.7364
# Epoch 18/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5406 - accuracy: 0.7372
# Epoch 19/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5401 - accuracy: 0.7367
# Epoch 20/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5398 - accuracy: 0.7367
# Epoch 21/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5400 - accuracy: 0.7368
# Epoch 22/75
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5391 - accuracy: 0.7378
# Epoch 23/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5385 - accuracy: 0.7372
# Epoch 24/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5378 - accuracy: 0.7377
# Epoch 25/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5382 - accuracy: 0.7383
# Epoch 26/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5380 - accuracy: 0.7394
# Epoch 27/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5374 - accuracy: 0.7379
# Epoch 28/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5377 - accuracy: 0.7372
# Epoch 29/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5369 - accuracy: 0.7384
# Epoch 30/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5373 - accuracy: 0.7381
# Epoch 31/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5365 - accuracy: 0.7391
# Epoch 32/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5367 - accuracy: 0.7386
# Epoch 33/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5362 - accuracy: 0.7388
# Epoch 34/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5362 - accuracy: 0.7397
# Epoch 35/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.7375
# Epoch 36/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5361 - accuracy: 0.7394
# Epoch 37/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5358 - accuracy: 0.7390
# Epoch 38/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5355 - accuracy: 0.7384
# Epoch 39/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 40/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 41/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 42/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5348 - accuracy: 0.7393
# Epoch 43/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5350 - accuracy: 0.7400
# Epoch 44/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5348 - accuracy: 0.7397
# Epoch 45/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7397
# Epoch 46/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5338 - accuracy: 0.7394
# Epoch 47/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5345 - accuracy: 0.7393
# Epoch 48/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7410
# Epoch 49/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5343 - accuracy: 0.7393
# Epoch 50/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.7402
# Epoch 51/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5340 - accuracy: 0.7403
# Epoch 52/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 53/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5338 - accuracy: 0.7407
# Epoch 54/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5334 - accuracy: 0.7400
# Epoch 55/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5333 - accuracy: 0.7400
# Epoch 56/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5334 - accuracy: 0.7414
# Epoch 57/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7404
# Epoch 58/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5331 - accuracy: 0.7411
# Epoch 59/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5329 - accuracy: 0.7407
# Epoch 60/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 61/75
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5333 - accuracy: 0.7406
# Epoch 62/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5328 - accuracy: 0.7411
# Epoch 63/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5326 - accuracy: 0.7408
# Epoch 64/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5323 - accuracy: 0.7403
# Epoch 65/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7402
# Epoch 66/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7402
# Epoch 67/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7403
# Epoch 68/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5319 - accuracy: 0.7411
# Epoch 69/75
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 70/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5323 - accuracy: 0.7416
# Epoch 71/75
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5321 - accuracy: 0.7422
# Epoch 72/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5320 - accuracy: 0.7408
# Epoch 73/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7411
# Epoch 74/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7418
# Epoch 75/75
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7407

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5563 - accuracy: 0.7268 - 507ms/epoch - 2ms/step
# Loss: 0.5563453435897827, Accuracy: 0.7267638444900513

# %%
# |# Export our model to HDF5 file
nn_model.save("/content/drive/MyDrive/Colab SMU/Deep Learning Homework/model6.h5")
