# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("/content/drive/MyDrive/Colab SMU/Deep Learning Homework/Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EIN                     34299 non-null  int64
#  1   NAME                    34299 non-null  object
#  2   APPLICATION_TYPE        34299 non-null  object
#  3   AFFILIATION             34299 non-null  object
#  4   CLASSIFICATION          34299 non-null  object
#  5   USE_CASE                34299 non-null  object
#  6   ORGANIZATION            34299 non-null  object
#  7   STATUS                  34299 non-null  int64
#  8   INCOME_AMT              34299 non-null  object
#  9   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  10  ASK_AMT                 34299 non-null  int64
#  11  IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 3.1+ MB

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis =1)

# %%
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION  ... ASK_AMT IS_SUCCESSFUL
# 0              T10       Independent  ...    5000             1
# 1               T3       Independent  ...  108590             1
# 2               T5  CompanySponsored  ...    5000             0
# 3               T3  CompanySponsored  ...    6692             1
# 4               T3       Independent  ...  142590             1
#
# [5 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
for col in application_df.columns:
  if col not in ["STATUS", "ASK_AMT"]:
    print(col)
    print(len(application_df[col].value_counts()))
    print()
# Out:
# APPLICATION_TYPE
# 17
#
# AFFILIATION
# 6
#
# CLASSIFICATION
# 71
#
# USE_CASE
# 5
#
# ORGANIZATION
# 4
#
# INCOME_AMT
# 9
#
# SPECIAL_CONSIDERATIONS
# 2
#
# IS_SUCCESSFUL
# 2

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.APPLICATION_TYPE.value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df.APPLICATION_TYPE.value_counts().plot(kind= "bar")
plt.show()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# use 500 for cutoff as well
cutoff = 100
app_vals = application_df.APPLICATION_TYPE.value_counts()
application_types_to_replace = list(app_vals[app_vals < cutoff].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1570        1
# C1900        1
# C1728        1
# C2380        1
# C4500        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
application_df.CLASSIFICATION.value_counts().plot.kde()
plt.show()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_vals = application_df.CLASSIFICATION.value_counts()
class_vals[class_vals > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C2710        3
# C0           3
# C1260        3
# C1246        2
# C1234        2
# C3200        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 100
class_vals = application_df.CLASSIFICATION.value_counts()
classifications_to_replace = list(class_vals[class_vals < cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                         1                         0
# 1       1   108590  ...                         1                         0
# 2       1     5000  ...                         1                         0
# 3       1     6692  ...                         1                         0
# 4       1   142590  ...                         1                         0
#
# [5 rows x 51 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop("IS_SUCCESSFUL", axis = 1)
y = application_df.IS_SUCCESSFUL

# Split the preprocessed data into a training and testing dataset
# Use sklearn to split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=32)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425],
#        [ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425],
#        [ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425],
#        ...,
#        [ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425],
#        [ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425],
#        [ 0.01247081, -0.0329289 , -0.06056052, ..., -0.07370801,
#          0.02789425, -0.02789425]])

# %%
X.head()
# Out:
#    STATUS  ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0       1     5000  ...                         1                         0
# 1       1   108590  ...                         1                         0
# 2       1     5000  ...                         1                         0
# 3       1     6692  ...                         1                         0
# 4       1   142590  ...                         1                         0
#
# [5 rows x 50 columns]

# %%
print(len(X.columns))
# Out:
# 50

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=len(X.columns)))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                816
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,105
# Trainable params: 1,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5859 - accuracy: 0.7053
# Epoch 2/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5578 - accuracy: 0.7274
# Epoch 3/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5535 - accuracy: 0.7292
# Epoch 4/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7289
# Epoch 5/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5501 - accuracy: 0.7304
# Epoch 6/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5492 - accuracy: 0.7306
# Epoch 7/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5487 - accuracy: 0.7314
# Epoch 8/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7303
# Epoch 9/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5475 - accuracy: 0.7322
# Epoch 10/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5472 - accuracy: 0.7325
# Epoch 11/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7320
# Epoch 12/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7321
# Epoch 13/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.7328
# Epoch 14/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7327
# Epoch 15/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7325
# Epoch 16/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5447 - accuracy: 0.7334
# Epoch 17/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7333
# Epoch 18/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7328
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7329
# Epoch 20/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7326
# Epoch 21/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7347
# Epoch 22/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7338
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7334
# Epoch 24/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7348
# Epoch 25/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7344
# Epoch 26/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7335
# Epoch 27/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7345
# Epoch 28/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7345
# Epoch 29/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7348
# Epoch 30/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7356
# Epoch 31/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7352
# Epoch 32/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7345
# Epoch 33/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7338
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7360
# Epoch 35/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7350
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7341
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7357
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7346
# Epoch 39/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7359
# Epoch 40/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7358
# Epoch 41/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7345
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7341
# Epoch 43/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7353
# Epoch 44/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7356
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7350
# Epoch 46/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7354
# Epoch 47/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7358
# Epoch 48/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7351
# Epoch 49/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7359
# Epoch 50/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7353

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5479 - accuracy: 0.7327 - 448ms/epoch - 2ms/step
# Loss: 0.5479444861412048, Accuracy: 0.7327113747596741

# %%
# # Export our model to HDF5 file
# nn_model.save("/content/drive/MyDrive/Colab SMU/Deep Learning Homework/model1.h5")
